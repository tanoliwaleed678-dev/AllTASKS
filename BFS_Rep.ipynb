# %%
graph = {
    '5': ['3', '7'],
    '3': ['2', '4'],
    '7': ['8'],
    '2': [],
    '4': ['8'],
    '8': []
}

visited = []
queue = []

def bfs(visited, graph, node):
    visited.append(node)
    queue.append(node)

    while queue:
        m = queue.pop(0)
        print(m, end=" ")

        for neighbour in graph[m]:
            if neighbour not in visited:
                visited.append(neighbour)
                queue.append(neighbour)

print("Following is the Breadth-First Search:")
bfs(visited, graph, '5')
# Out:
# Following is the Breadth-First Search:
# 5 3 7 2 4 8

# %%
# -----------------------------
# ACTIVITY 2: BFS FOR TREE
# -----------------------------

tree = {
    1: [2, 3, 4],
    2: [1, 5, 6],
    3: [1],
    4: [1, 7],
    5: [2],
    6: [2],
    7: [4]
}

visited = []
queue = []

def bfs_tree(visited, graph, node):
    visited.append(node)
    queue.append(node)

    while queue:
        m = queue.pop(0)
        print(m, end=" ")

        for child in graph[m]:
            if child not in visited:
                visited.append(child)
                queue.append(child)

print("BFS Traversal for Tree:")
bfs_tree(visited, tree, 1)
# Out:
# BFS Traversal for Tree:
# 1 2 3 4 5 6 7

# %%
tree = {
    1: [2, 3, 4],
    2: [1, 5, 6],
    3: [1],
    4: [1, 7],
    5: [2],
    6: [2],
    7: [4]
}

visited = []
queue = []

def bfs_tree(graph, start):
    visited.append(start)
    queue.append(start)

    while queue:
        node = queue.pop(0)
        print(node, end=" ")

        for child in graph[node]:
            if child not in visited:
                visited.append(child)
                queue.append(child)

print("BFS Tree Traversal:")
bfs_tree(tree, 1)
# Out:
# BFS Tree Traversal:
# 1 2 3 4 5 6 7

# %%
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': ['G'],
    'F': [],
    'G': []
}

visited = []
queue = []

def bfs(graph, start):
    visited.append(start)
    queue.append(start)

    while queue:
        node = queue.pop(0)
        print(node, end=" ")

        for neighbor in graph[node]:
            if neighbor not in visited:
                visited.append(neighbor)
                queue.append(neighbor)

print("BFS Activity 3:")
bfs(graph, 'A')
# Out:
# BFS Activity 3:
# A B C D E F G

# %%
from collections import deque

graph = {
    'A': [('B', 1), ('C', 4)],
    'B': [('D', 2), ('E', 5)],
    'C': [('F', 1)],
    'D': [],
    'E': [('G', 3)],
    'F': [],
    'G': []
}

def bfs_cost(graph, start, goal):
    queue = deque()
    queue.append((start, 0))  # (node, cost)

    visited = set()

    while queue:
        node, cost = queue.popleft()

        print(node, "Cost:", cost)

        if node == goal:
            print("GOAL REACHED")
            print("Total Cost:", cost)
            return

        if node not in visited:
            visited.add(node)

            for neighbor, weight in graph[node]:
                queue.append((neighbor, cost + weight))

bfs_cost(graph, 'A', 'G')
# Out:
# A Cost: 0
# B Cost: 1
# C Cost: 4
# D Cost: 3
# E Cost: 6
# F Cost: 5
# G Cost: 9
# GOAL REACHED
# Total Cost: 9

# %%
romania = {
    'Arad': [('Zerind', 75), ('Sibiu', 140), ('Timisoara', 118)],
    'Zerind': [('Oradea', 71)],
    'Oradea': [('Sibiu', 151)],
    'Sibiu': [('Fagaras', 99), ('Rimnicu', 80)],
    'Timisoara': [('Lugoj', 111)],
    'Lugoj': [('Mehadia', 70)],
    'Mehadia': [('Drobeta', 75)],
    'Drobeta': [('Craiova', 120)],
    'Rimnicu': [('Craiova', 146)],
    'Craiova': [('Pitesti', 138)],
    'Fagaras': [('Bucharest', 211)],
    'Pitesti': [('Bucharest', 101)],
    'Bucharest': []
}

# %%
from collections import deque

def bfs_path(graph, start, goal):
    queue = deque()
    queue.append((start, [start], 0))

    visited = set()

    while queue:
        node, path, cost = queue.popleft()

        print("Visiting:", node)

        if node == goal:
            print("\nPATH:", " -> ".join(path))
            print("TOTAL DISTANCE:", cost)
            return

        if node not in visited:
            visited.add(node)

            for neighbor, weight in graph[node]:
                queue.append((neighbor, path + [neighbor], cost + weight))

bfs_path(romania, 'Arad', 'Bucharest')
# Out:
# Visiting: Arad
# Visiting: Zerind
# Visiting: Sibiu
# Visiting: Timisoara
# Visiting: Oradea
# Visiting: Fagaras
# Visiting: Rimnicu
# Visiting: Lugoj
# Visiting: Sibiu
# Visiting: Bucharest
#
# PATH: Arad -> Sibiu -> Fagaras -> Bucharest
# TOTAL DISTANCE: 450
